# %% [markdown]
# <a href="https://colab.research.google.com/github/sohmxdd/LuminaScope-Lite/blob/main/notebooks/LuminaScope_Lite.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/sohmxdd/LuminaScope-Lite.git
# %cd LuminaScope-Lite

# %%
# !pip install tensorflow numpy pandas matplotlib scikit-learn
